# %% [markdown]
# ### Task 2: Quantitative Analysis of Stock price
#
# #### import liberaries

# %%
import os
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import talib as ta
sys.path.insert(0, os.path.dirname(os.getcwd()))
# import stockpriceanalyzer from scripts
from scripts.stock_analyzer import StockPriceAnalyzer

# %%
# assign folder path of datasets 
folder_path='/Kiffya_10_acc/Nova-Financial-Solutions/data/yfinance_data/'
# Automaticaly merge the data and create a single csv file and asign to sa.data
sa=StockPriceAnalyzer(folder_path=folder_path)

# %%
# Display the first five row datas after merging
sa.data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#    Dividends  Stock Splits stock_symbol
# 0        0.0           0.0         AAPL
# 1        0.0           0.0         AAPL
# 2        0.0           0.0         AAPL
# 3        0.0           0.0         AAPL
# 4        0.0           0.0         AAPL

# %%
# make sure the dataframe includes columns like Open, High, Low, Close, and Volume.
sa.data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'stock_symbol'],
#       dtype='object')

# %% [markdown]
# ####  Apply Analysis Indicators with TA-Lib

# %%
# Calculate technical indicators using TA-Lib and desplay the data
stock_data=sa.calculate_technical_indicators(sa.data)
stock_data
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 45423  2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 45424  2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 45425  2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 45426  2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# 45427  2024-07-30  232.250000  232.410004  220.000000  222.619995  222.619995
#
# ...

# %% [markdown]
# #### Plot Analaysis of technical indicator

# %%
sa.visualize_stocks(sa.data)

# %%
#Close Price over time for different stock symbols
sa.plot_price()

# %% [markdown]
# ### Use PyNance for Financial Metrics

# %%
# calculate financial metrics and add one column called 'Returns' to the dataframe
# and display sample dataset
sa.calculate_financial_metrics()
# Out:
#                            Date        Open        High         Low  \
# 0     1980-12-12 00:00:00+00:00    0.128348    0.128906    0.128348
# 1     1980-12-15 00:00:00+00:00    0.122210    0.122210    0.121652
# 2     1980-12-16 00:00:00+00:00    0.113281    0.113281    0.112723
# 3     1980-12-17 00:00:00+00:00    0.115513    0.116071    0.115513
# 4     1980-12-18 00:00:00+00:00    0.118862    0.119420    0.118862
# ...                         ...         ...         ...         ...
# 45423 2024-07-24 00:00:00+00:00  225.419998  225.990005  214.710007
# 45424 2024-07-25 00:00:00+00:00  216.800003  226.000000  216.229996
# 45425 2024-07-26 00:00:00+00:00  221.190002  222.279999  215.330002
# 45426 2024-07-29 00:00:00+00:00  224.899994  234.270004  224.699997
# 45427 2024-07-30 00:00:00+00:00  232.250000  232.410004  220.000000
#
#             Close   Adj Close     Volume  Dividends  Stock Splits  \
# 0        0.128348    0.098943  469033600        0.0           0.0
# ...

# %%
# plot sock price return over time
sa.plot_financial_metrics()

# %% [markdown]
# <center>
#
# ## End!
#
# </center>
